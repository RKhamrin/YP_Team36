# %% [markdown]
# **Data Merging**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
schedule = pd.read_csv("match_log_schedule.csv")
schedule.rename(columns = {'Unnamed: 0':'league',	'Unnamed: 1':'season','Unnamed: 2':'team','Unnamed: 3':'game'}, inplace = True)
#match_stata.drop(index=[0,1], inplace = True)
schedule.drop('league', axis = 1, inplace = True)
schedule.reset_index(inplace = True,drop = True)
schedule
# Out:
#        season     team                              game        date  \
# 0        2223  Ajaccio  2023-01-08 Jura Sud Foot-Ajaccio  2023-01-08
# 1        2223  Ajaccio       2023-01-21 Toulouse-Ajaccio  2023-01-21
# 2        1718   Alavés          2017-10-24 Getafe-Alavés  2017-10-24
# 3        1718   Alavés          2017-11-30 Alavés-Getafe  2017-11-30
# 4        1718   Alavés   2018-01-03 SD Formentera-Alavés  2018-01-03
# ...       ...      ...                               ...         ...
# 10410    2324   Wolves       2024-01-28 West Brom-Wolves  2024-01-28
# 10411    2324   Wolves        2024-02-28 Wolves-Brighton  2024-02-28
# 10412    2324   Wolves   2024-03-16 Wolves-Coventry City  2024-03-16
# 10413    2425   Wolves         2024-08-28 Wolves-Burnley  2024-08-28
# 10414    2425   Wolves        2024-09-18 Brighton-Wolves  2024-09-18
#
#            time                round  day venue result GF  ...  xG xGA  Poss  \
# 0      15:30:00          Round of 64  Sun  Away      W  2  ... NaN NaN  55.0
# 1      18:00:00          Round of 32  Sat  Away      L  0  ... NaN NaN  37.0
# 2      20:30:00          Round of 32  Tue  Away      W  1  ... NaN NaN   NaN
# 3      19:00:00          Round of 32  Thu  Home      W  3  ... NaN NaN   NaN
# 4      19:00:00          Round of 16  Wed  Away      W  3  ... NaN NaN   NaN
# ...         ...                  ...  ...   ...    ... ..  ...  ..  ..   ...
# 10410  11:45:00  Fourth round proper  Sun  Away      W  2  ... NaN NaN  49.0
# 10411  19:45:00   Fifth round proper  Wed  Home      W  1  ... NaN NaN  28.0
# 10412  12:15:00       Quarter-finals  Sat  Home      L  2  ... NaN NaN  58.0
# 10413  19:30:00         Second round  Wed  Home      W  2  ... NaN NaN  50.0
# 10414  19:45:00          Third round  Wed  Away      L  2  ... NaN NaN  46.0
#
#        Attendance            Captain  Formation Opp Formation  \
# 0          1957.0  Vincent Marchetti    4-2-3-1       4-2-3-1
# 1         18708.0         Riad Nouri      4-4-2         4-3-3
# 2          7731.0                NaN        NaN           NaN
# 3          9128.0                NaN        NaN           NaN
# 4          1100.0                NaN        NaN           NaN
# ...           ...                ...        ...           ...
# 10410     25013.0         Max Kilman      3-4-3       4-1-4-1
# 10411     23822.0         Max Kilman    3-4-1-2         3-4-3
# 10412     31262.0         Max Kilman      3-4-3       4-2-3-1
# 10413     19236.0       Craig Dawson    4-2-3-1       4-4-1-1
# 10414     16018.0        Tommy Doyle    4-2-3-1         4-4-2
#
#                    Referee                                       match_report  \
# 0       Stéphanie Frappart  /en/matches/9e1109e9/Jura-Sud-Foot-Ajaccio-Jan...
# 1        François Letexier  /en/matches/c9a9802b/Toulouse-Ajaccio-January-...
# 2          David Fernández  /en/matches/6a0efeb3/Getafe-Alaves-October-24-...
# 3            José González  /en/matches/00b829fc/Alaves-Getafe-November-30...
# 4      Alejandro Hernández  /en/matches/b7c26577/SD-Formentera-Alaves-Janu...
# ...                    ...                                                ...
# 10410       Thomas Bramall  /en/matches/2a3327b0/West-Bromwich-Albion-Wolv...
# 10411          Andy Madley  /en/matches/f890fce5/Wolverhampton-Wanderers-B...
# 10412       Samuel Barrott  /en/matches/3650b3eb/Wolverhampton-Wanderers-C...
# 10413         Joshua Smith  /en/matches/c881bced/Wolverhampton-Wanderers-B...
# 10414          John Brooks  /en/matches/9ffb2eb2/Brighton-and-Hove-Albion-...
#
#                         Notes
# 0                         NaN
# 1                         NaN
# 2                  Leg 1 of 2
# 3      Leg 2 of 2; Alavés won
# 4                  Leg 1 of 2
# ...                       ...
# 10410                     NaN
# 10411                     NaN
# 10412                     NaN
# 10413                     NaN
# 10414                     NaN
#
# [10415 rows x 22 columns]

# %%
names = ['defense','gscreation','keeper','passing','passtypes','possession','shooting']

# %%
match_stats = schedule.copy()

# %%
for i in names:
  d = pd.read_csv("match_log_"+i+".csv")
  d.rename(columns = {'Unnamed: 0':'league',	'Unnamed: 1':'season','Unnamed: 2':'team','Unnamed: 3':'game'}, inplace = True)
  d.drop(index=[0,1], inplace = True)
  d.drop('league', axis = 1, inplace = True)
  d.reset_index(inplace = True,drop = True)
  match_stats = pd.merge(match_stats, d, on = ['game','team'], suffixes=('_x', '_y'), how = 'left')
  match_stats = match_stats.loc[:, ~match_stats.columns.str.endswith('_y')]
  match_stats.rename(columns=lambda x: x.replace('_x', '') if '_x' in x else x, inplace=True)

# %%
d = pd.read_csv("match_log_misc.csv")
d.rename(columns = {'Unnamed: 0':'league',	'Unnamed: 1':'season','Unnamed: 2':'team','Unnamed: 3':'game','Performance':'yellow','Performance.1':'red','Performance.2':'sec_yel','Performance.3':'fouls_com','Performance.4':'fouls_drw','Performance.5':'offside','Performance.6':'crosses','Performance.7':'intercep','Performance.8':'tackles won','Performance.9':'PKwon','Performance.10':'PKcon','Performance.11':'OwnGoals','Performance.12':'BallRecov'}, inplace = True)
d.drop(index=[0,1], inplace = True)
d.drop('league', axis = 1, inplace = True)
d.reset_index(inplace = True,drop = True)
match_stats = pd.merge(match_stats, d, on = ['game','team'], suffixes=('_x', '_y'), how = 'left')
match_stats = match_stats.loc[:, ~match_stats.columns.str.endswith('_y')]
match_stats.rename(columns=lambda x: x.replace('_x', '') if '_x' in x else x, inplace=True)

# %%
match_stats
# Out:
#        season     team                              game        date  \
# 0        2223  Ajaccio  2023-01-08 Jura Sud Foot-Ajaccio  2023-01-08
# 1        2223  Ajaccio       2023-01-21 Toulouse-Ajaccio  2023-01-21
# 2        1718   Alavés          2017-10-24 Getafe-Alavés  2017-10-24
# 3        1718   Alavés          2017-11-30 Alavés-Getafe  2017-11-30
# 4        1718   Alavés   2018-01-03 SD Formentera-Alavés  2018-01-03
# ...       ...      ...                               ...         ...
# 10410    2324   Wolves       2024-01-28 West Brom-Wolves  2024-01-28
# 10411    2324   Wolves        2024-02-28 Wolves-Brighton  2024-02-28
# 10412    2324   Wolves   2024-03-16 Wolves-Coventry City  2024-03-16
# 10413    2425   Wolves         2024-08-28 Wolves-Burnley  2024-08-28
# 10414    2425   Wolves        2024-09-18 Brighton-Wolves  2024-09-18
#
#            time                round  day venue result GF  ... crosses  \
# 0      15:30:00          Round of 64  Sun  Away      W  2  ...      17
# 1      18:00:00          Round of 32  Sat  Away      L  0  ...      11
# 2      20:30:00          Round of 32  Tue  Away      W  1  ...     NaN
# 3      19:00:00          Round of 32  Thu  Home      W  3  ...     NaN
# 4      19:00:00          Round of 16  Wed  Away      W  3  ...     NaN
# ...         ...                  ...  ...   ...    ... ..  ...     ...
# 10410  11:45:00  Fourth round proper  Sun  Away      W  2  ...      14
# 10411  19:45:00   Fifth round proper  Wed  Home      W  1  ...      10
# 10412  12:15:00       Quarter-finals  Sat  Home      L  2  ...      26
# 10413  19:30:00         Second round  Wed  Home      W  2  ...      16
# 10414  19:45:00          Third round  Wed  Away      L  2  ...      13
#
#       intercep  tackles won  PKwon  PKcon  OwnGoals BallRecov Aerial Duels  \
# 0           10            9    NaN    NaN         0       NaN          NaN
# 1           16           12    NaN    NaN         0       NaN          NaN
# 2          NaN          NaN    NaN    NaN         0       NaN          NaN
# 3          NaN          NaN    NaN    NaN         0       NaN          NaN
# 4          NaN          NaN    NaN    NaN         0       NaN          NaN
# ...        ...          ...    ...    ...       ...       ...          ...
# 10410       19            4    NaN    NaN         0       NaN          NaN
# 10411        7           11    NaN    NaN         0       NaN          NaN
# 10412        8           15    NaN    NaN         0       NaN          NaN
# 10413       12           18    NaN    NaN         0       NaN          NaN
# 10414       14           17    NaN    NaN         0       NaN          NaN
#
#       Aerial Duels.1 Aerial Duels.2
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ...              ...            ...
# 10410            NaN            NaN
# 10411            NaN            NaN
# 10412            NaN            NaN
# 10413            NaN            NaN
# 10414            NaN            NaN
#
# [10415 rows x 168 columns]

# %%
match_stats.to_csv('match_stats.csv')

# %% [markdown]
# Обработка данных

# %%
#match_stats = pd.read_csv("match_stats.csv")

# %%
### Description
description = match_stats.describe(include = 'all')
description.to_csv("dataset_descr.csv")

# %%
description
# Out:
#               season           team                           game  \
# count   10415.000000          10415                          10415
# unique           NaN            148                           6720
# top              NaN  Bayern Munich  2018-01-24 Paris S-G-Guingamp
# freq             NaN            391                              2
# mean     2058.888334            NaN                            NaN
# std       228.094321            NaN                            NaN
# min      1718.000000            NaN                            NaN
# 25%      1819.000000            NaN                            NaN
# 50%      2021.000000            NaN                            NaN
# 75%      2223.000000            NaN                            NaN
# max      2425.000000            NaN                            NaN
#
#               date      time        round    day  venue result    GF  ...  \
# count        10415     10034        10415  10415  10415   9745  9746  ...
# unique        1507        72           66      7      3      3    58  ...
# top     2023-11-01  15:30:00  Group stage    Sat   Away      W     1  ...
# freq            31      2811         1386   3570   5333   4541  2798  ...
# mean           NaN       NaN          NaN    NaN    NaN    NaN   NaN  ...
# std            NaN       NaN          NaN    NaN    NaN    NaN   NaN  ...
# min            NaN       NaN          NaN    NaN    NaN    NaN   NaN  ...
# 25%            NaN       NaN          NaN    NaN    NaN    NaN   NaN  ...
# 50%            NaN       NaN          NaN    NaN    NaN    NaN   NaN  ...
# 75%            NaN       NaN          NaN    NaN    NaN    NaN   NaN  ...
# max            NaN       NaN          NaN    NaN    NaN    NaN   NaN  ...
#
#        crosses intercep  tackles won  PKwon  PKcon  OwnGoals BallRecov  \
# count     9255     9255         9255   7062   7062      9651      6706
# unique      62       32           31      4      4         3        74
# top         15        8            9      0      0         0        53
# freq       509      839          952   6217   6080      9295       281
# mean       NaN      NaN          NaN    NaN    NaN       NaN       NaN
# std        NaN      NaN          NaN    NaN    NaN       NaN       NaN
# min        NaN      NaN          NaN    NaN    NaN       NaN       NaN
# 25%        NaN      NaN          NaN    NaN    NaN       NaN       NaN
# 50%        NaN      NaN          NaN    NaN    NaN       NaN       NaN
# 75%        NaN      NaN          NaN    NaN    NaN       NaN       NaN
# max        NaN      NaN          NaN    NaN    NaN       NaN       NaN
#
#        Aerial Duels Aerial Duels.1 Aerial Duels.2
# count          6706           6706           6706
# unique           49             47            408
# top              12             11           50.0
# freq            417            419            428
# mean            NaN            NaN            NaN
# std             NaN            NaN            NaN
# min             NaN            NaN            NaN
# 25%             NaN            NaN            NaN
# 50%             NaN            NaN            NaN
# 75%             NaN            NaN            NaN
# max             NaN            NaN            NaN
#
# [11 rows x 168 columns]

# %%
### NAs
match_stats.isna().sum()
# Out:
# season               0
# team                 0
# game                 0
# date                 0
# time               381
#                   ...
# OwnGoals           764
# BallRecov         3709
# Aerial Duels      3709
# Aerial Duels.1    3709
# Aerial Duels.2    3709
# Length: 168, dtype: int64

# %%
#количество NaN строк
na_share = match_stats.isna().sum()/10415

# %%
shares = na_share.sort_values(ascending = False)

# %%
#average density of dataset
print(f"Share of nas:{shares.mean()}", f"Share of values: {1-shares.mean()}", sep = '\n')
# Out:
# Share of nas:0.27470166655236267
# Share of values: 0.7252983334476373

# %% [markdown]
# Dataset density can be assessed as 0,72 out of 1, which means that dataset sparsity is medium.

# %% [markdown]
# Две основные гипотезы присутствия NaN
# 1. В датасете присутствует часть schedule (раписание), которая включает в себя все матчи, в том числе и еще не состоявшиеся (т.к. мы смотрим на сезон 2024-2025). Решить проблему можно, выкинув все строки, которые находятся "в будущем" относительно сегодняшнего дня.
# 2. Не все статистики доступны для всех команд, для более популярных матчей, скорее всего, статистик будет больше, чем для менее популярных (можно определить по аттрибуту attendance). Например, в датасете есть такие матчи, запись о посещамости которых даже неизвестна. В таком случае эти NA не отработать, так как они буквально означают отсутствие записи данных о матче.
# 3. Возможно, есть колонки, в которых NA может быть отдельным значением - необходимо это проверить.

# %%
#1
match_stats = match_stats[match_stats['date']<'2024-11-04']

# %%
#Доля density увеличилась за счет выкидывания строк несостоявшихся матчей
na_share1 = match_stats.count()/len(match_stats)
na_share1.mean()
# Out:
# 0.7697283784574002

# %%
#2
match_stats_num = match_stats.select_dtypes(include=['number']).columns

# %%
#создаем словарь для каждой такой колонки и прописываем правило.
# для всех числовых, кроме Att мы берем count, чтобы посмотреть на количество значений.
# Для Att берем среднее, чтобы получить среднюю посещаемость матчей
d = {}
for i in match_stats_num:
  if i != "Attendance":
    d[i] = 'count'
  else:
    d[i] = 'mean'

# %%
t = match_stats.groupby(by = 'team')[match_stats_num].agg(d).sort_values(by = 'Attendance', ascending = False)
t
# Out:
#                 season   xG  xGA  Poss    Attendance  Int  Tkl+Int  Clr  Err  \
# team
# Dortmund           346  314  314   344  54668.871972  344      345  314  314
# Manchester Utd     134   74   74   134  54667.192661  134      134   74   74
# Bayern Munich      361  322  322   359  53625.721088  359      360  322  322
# Barcelona          120   72   72   108  53511.570000  109      120   72   72
# Real Madrid        126   82   82   116  51192.853211  117      126   82   82
# ...                ...  ...  ...   ...           ...  ...      ...  ...  ...
# Parma                8    0    0     4   3838.000000    7        8    0    0
# Venezia              4    0    0     4   3134.000000    4        4    0    0
# Almería              3    0    0     3   2706.000000    3        3    0    0
# Empoli               8    0    0     7   2296.500000    7        8    0    0
# Chievo               4    0    0     0   1959.500000    0        4    0    0
#
#                 Ast  xAG   xA   KP  1/3  PPA  CrsPA  PrgP  Att
# team
# Dortmund        345  314  314  314  314  314    314   314  314
# Manchester Utd  134   74   74   74   74   74     74    74   74
# Bayern Munich   360  322  322  322  322  322    322   322  322
# Barcelona       120   72   72   72   72   72     72    72   72
# Real Madrid     126   82   82   82   82   82     82    82   82
# ...             ...  ...  ...  ...  ...  ...    ...   ...  ...
# Parma             8    0    0    0    0    0      0     0    0
# Venezia           4    0    0    0    0    0      0     0    0
# Almería           3    0    0    0    0    0      0     0    0
# Empoli            8    0    0    0    0    0      0     0    0
# Chievo            4    0    0    0    0    0      0     0    0
#
# [148 rows x 18 columns]

# %%
sns.scatterplot(data=t,x='Attendance', y='Att')
# Out:
# <Axes: xlabel='Attendance', ylabel='Att'>

# %% [markdown]
# Видно, что вторая гипотеза не может быть частично доказана. Действительно, для команд, чьи игры в среднем посещаются меньше, будут иметь меньше статистик. Начиная с определенного уровня посещаемости матей команды число статистик растет

# %% [markdown]
# 3. NA не имеют под собой адекватного значения, нет значений "флагов". NA возникают только в случае отсутствия данных

# %%
# Обработка NaN
match_stats.dropna()
# Если удалим все строки, в которых встречаются NaN - останется очень маленькая выборка
# Удалим только те, в которых доля NA наибольшая
# Out:
#        season       team                            game        date  \
# 138      1718    Arsenal    2018-02-15 Östersund-Arsenal  2018-02-15
# 139      1718    Arsenal    2018-02-22 Arsenal-Östersund  2018-02-22
# 141      1718    Arsenal        2018-03-08 Milan-Arsenal  2018-03-08
# 143      1718    Arsenal  2018-04-05 Arsenal-CSKA Moscow  2018-04-05
# 144      1718    Arsenal  2018-04-12 CSKA Moscow-Arsenal  2018-04-12
# ...       ...        ...                             ...         ...
# 10045    2324   West Ham  2024-04-18 West Ham-Leverkusen  2024-04-18
# 10155    1920  Wolfsburg      2020-02-20 Wolfsburg-Malmö  2020-02-20
# 10157    1920  Wolfsburg      2020-02-27 Malmö-Wolfsburg  2020-02-27
# 10387    1920     Wolves      2020-02-20 Wolves-Espanyol  2020-02-20
# 10388    1920     Wolves      2020-02-27 Espanyol-Wolves  2020-02-27
#
#            time           round  day venue result GF  ... crosses intercep  \
# 138    19:00:00     Round of 32  Thu  Away      W  3  ...      10       12
# 139    20:05:00     Round of 32  Thu  Home      L  1  ...      15       10
# 141    19:00:00     Round of 16  Thu  Away      W  2  ...       8       15
# 143    20:05:00  Quarter-finals  Thu  Home      W  4  ...      10       13
# 144    22:05:00  Quarter-finals  Thu  Away      D  2  ...      13       16
# ...         ...             ...  ...   ...    ... ..  ...     ...      ...
# 10045  20:00:00  Quarter-finals  Thu  Home      D  1  ...      26        6
# 10155  21:00:00     Round of 32  Thu  Home      W  2  ...      26        7
# 10157  18:55:00     Round of 32  Thu  Away      W  3  ...      11       13
# 10387  20:00:00     Round of 32  Thu  Home      W  4  ...      13       17
# 10388  18:55:00     Round of 32  Thu  Away      L  2  ...       8       13
#
#        tackles won  PKwon  PKcon  OwnGoals BallRecov Aerial Duels  \
# 138             11      0      1         0        67            4
# 139             11      0      0         0        70           10
# 141              8      0      0         0        57           25
# 143              8      1      0         0        54           11
# 144             10      0      0         0        64           30
# ...            ...    ...    ...       ...       ...          ...
# 10045           10      0      0         0        37           15
# 10155            6      0      1         0        53           10
# 10157           11      0      0         0        60           12
# 10387            9      0      0         0        54           23
# 10388           11      0      1         0        53           21
#
#       Aerial Duels.1 Aerial Duels.2
# 138                0          100.0
# 139                7           58.8
# 141               15           62.5
# 143               12           47.8
# 144               12           71.4
# ...              ...            ...
# 10045             21           41.7
# 10155             15           40.0
# 10157             14           46.2
# 10387             18           56.1
# 10388             16           56.8
#
# [542 rows x 168 columns]

# %%
#предлагаемтся оставить только те столбцы, в которых количество пропусков меньше среднего.
# Если посмотреть на столбцы, в которых пропусков больше всего, то это как правило очень "узкие" показатели:
# ожидаемое количество голов, пассов и тд - что по сути не является прямым показателем игры.
# При этом > 23% пропусков заполнить средним может быть невозможно из-за нехватки данных - тогда все
# данные будут около среднего и это теряет смысл. Обнулять такой большой % данных может быть
# опасно из-за того, например, что 0 в голах будет сильно смещать предсказание модели.
r = 1-na_share1
cols = r[r<= r.mean()].sort_values(ascending = False).reset_index()['index'].to_list()

# %%
match_stats = match_stats[cols]

# %%
#Заменяем NA на 0
# Процент NA достаточно небольшой для данных столбцов, поэтому можем так сделать.
match_stats.fillna('0', inplace = True)
# Out:
# <ipython-input-35-8ddc9c22ea0f>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   match_stats.fillna('0', inplace = True)

# %% [markdown]
# Таким образом, для того, чтобы убрать пропуски, мы
# 1. убрали будущие игры
# 2. убрали столбцы с большой долей пропусков, так как в выгрузке содержались все метрики, из которых многие не доступны для команд или не являются следствием матча (например, прогноз на матч)
# 3. В оставшихся столбцах NA занулили. В численных данных процент пропусков небольшой, поэтому значимого смещения не будет. В категориальных данных 0 означает любое другое значение, кроме существующих.

# %%
# Проверка на ошибочные данные: есть ли отрицательные и бесконечные данные? Есть ли лишние символы?

# %%
#Обработка лишних символов в колонка GA и GF (иногда там в скобках указывается значение противоположной переменной, в чем нет необходимости)
import re
def clean_value(value):
    # Удаляем содержимое в скобках и оставляем первый символ
    return re.sub(r'\s*\(.*\)', '', value)[0]

# Применяем функцию к колонке
match_stats['GF'] = match_stats['GF'].apply(clean_value)
match_stats['GA'] = match_stats['GA'].apply(clean_value)

# %%
match_stats.columns
# Out:
# Index(['Attendance', 'Performance.3', 'Standard.5', 'Poss', 'Standard.4',
#        'Standard.3', 'offside', 'crosses', 'fouls_drw', 'fouls_com',
#        'intercep', 'Pass Types.5', 'tackles won', 'Int', 'Tackles.1',
#        'Standard.1', 'Standard.2', 'Performance.2', 'Performance',
#        'Opp Formation', 'Formation', 'Captain', 'Referee', 'Performance.1',
#        'Performance.4', 'OwnGoals', 'Ast', 'Penalty Kicks.1',
#        'Penalty Kicks.2', 'Penalty Kicks.3', 'Penalty Kicks', 'Standard.9',
#        'Tkl+Int', 'Standard', 'sec_yel', 'red', 'yellow', 'Standard.8',
#        'match_report', 'result', 'GA', 'GF', 'time', 'round', 'game', 'date',
#        'team', 'day', 'venue', 'opponent', 'season'],
#       dtype='object')

# %%
tps={'Attendance':'int64','Performance.3':'float64','Standard.5':'float64','Poss':'float64','Standard.4':'float64','Standard.3':'float64','Tackles.1':'int64','tackles won':'int64','Pass Types.5':'int64','intercep':'int64','Int':'int64','Standard.2':'int64','Standard.1':'int64','Performance.2':'int64','Performance':'int64','Performance.1':'int64','Performance.4':'int64','OwnGoals':'int64','Ast':'int64','Penalty Kicks.2':'int64','Penalty Kicks.3':'int64','Penalty Kicks':'int64','Penalty Kicks.1':'int64','Standard':'int64','Standard.8':'int64','Standard.9':'int64','Tkl+Int':'int64','GA':'int64', 'GF':'int64'}

# %%
#меняем тип данных на корректный
match_stats = match_stats.astype(tps)

# %%
#Убираем лишние символы из колонки formation
match_stats['Formation'] = match_stats['Formation'].str.replace('◆','', regex = False)

# %%
#Проверяем наличие отрицательный значений

# %%
# Видим, что в Perormance присутствуют отрицательные значения.
#Колонка показывает Saves %
match_stats.describe().min()
# Out:
# Attendance           0.000000
# Performance.3     -100.000000
# Standard.5           0.000000
# Poss                 0.000000
# Standard.4           0.000000
# Standard.3           0.000000
# intercep             0.000000
# Pass Types.5         0.000000
# tackles won          0.000000
# Int                  0.000000
# Tackles.1            0.000000
# Standard.1           0.000000
# Standard.2           0.000000
# Performance.2        0.000000
# Performance          0.000000
# Performance.1        0.000000
# Performance.4        0.000000
# OwnGoals             0.000000
# Ast                  0.000000
# Penalty Kicks.1      0.000000
# Penalty Kicks.2      0.000000
# Penalty Kicks.3      0.000000
# Penalty Kicks        0.000000
# Standard.9           0.000000
# Tkl+Int              0.000000
# Standard             0.000000
# Standard.8           0.000000
# GA                   0.000000
# GF                   0.000000
# season             214.592035
# dtype: float64

# %% [markdown]
# В колонке Performance.3 могут быть отрицательные значения, так как столбец показывает % сейвов и рассчитывается как (Shots on Target Against - Goals Against)/Shots on Target Against. Shots on target может быть меньше Goals Against

# %% [markdown]
# В целевой (это либо исход матча, либо количество голов - будет понятно позднее) исход матча есть пропущенные значения, которые стали 0 после обраболта NaN. Такие строки нужно убрать.

# %%
match_stats = match_stats[match_stats['result'] != '0']

# %%
#Обработка выбросов
match_stats_num = match_stats.select_dtypes(include=['number']).columns

# %%
match_stats_num
# Out:
# Index(['Attendance', 'Performance.3', 'Standard.5', 'Poss', 'Standard.4',
#        'Standard.3', 'intercep', 'Pass Types.5', 'tackles won', 'Int',
#        'Tackles.1', 'Standard.1', 'Standard.2', 'Performance.2', 'Performance',
#        'Performance.1', 'Performance.4', 'OwnGoals', 'Ast', 'Penalty Kicks.1',
#        'Penalty Kicks.2', 'Penalty Kicks.3', 'Penalty Kicks', 'Standard.9',
#        'Tkl+Int', 'Standard', 'Standard.8', 'GA', 'GF', 'season'],
#       dtype='object')

# %%
Q1, Q3 = match_stats['Standard.4'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower, upper = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR

# %%
np.transpose(match_stats[(match_stats['Standard.4'] < lower) | (match_stats['Standard.4'] > upper)].index.to_list())
# Out:
# array([   45,    74,   107,   165,   181,   200,   203,   256,   268,
#          468,   528,   623,   640,   776,  1244,  1359,  1382,  1398,
#         1586,  1587,  1630,  1677,  1679,  1784,  1785,  1796,  1797,
#         2075,  2076,  2077,  2082,  2083,  2084,  2185,  2261,  2306,
#         2318,  2358,  2376,  2720,  2722,  2826,  2842,  2881,  2928,
#         3032,  3033,  3114,  3116,  3204,  3254,  3284,  3446,  3447,
#         3494,  3526,  3557,  3730,  3839,  3856,  3858,  3974,  4054,
#         4085,  4099,  4125,  4216,  4367,  4491,  4561,  5281,  5312,
#         5334,  5390,  5451,  5478,  5524,  5538,  5558,  5581,  5658,
#         5715,  5724,  5728,  5965,  5975,  6078,  6175,  6270,  6358,
#         6510,  6560,  6677,  6719,  6761,  6780,  6847,  6908,  6941,
#         7119,  7122,  7189,  7191,  7340,  7362,  7425,  7426,  7520,
#         7543,  7591,  7615,  7654,  7662,  7754,  7784,  7929,  8008,
#         8052,  8061,  8080,  8099,  8125,  8264,  8275,  8291,  8300,
#         8301,  8404,  8605,  8640,  8643,  8699,  8700,  8702,  8756,
#         8769,  8815,  8963,  9075,  9076,  9109,  9209,  9245,  9365,
#         9382,  9559,  9812,  9834,  9837, 10039, 10043, 10113, 10152,
#        10270])

# %%
for i in match_stats_num:
  Q1, Q3 = match_stats[i].quantile([0.25, 0.75])
  IQR = Q3 - Q1
  lower, upper = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
  if i == 'Attendance':
    t = match_stats[(match_stats[i] < lower) | (match_stats[i] > upper)]
  else:
    t = pd.concat([t,match_stats[(match_stats[i] < lower) | (match_stats[i] > upper)]], axis = 0)

# %% [markdown]
# Наибольшее количество выбросов наблюдаетс в переменных Poss (% of passess attempted). Данные представлены как % от 0 до 100, удаление выбросов некорректно для колонки данного содержания.

# %% [markdown]
# При построении модели мы еще посмотрим на выбросы и эффект от их удаления на модель.

# %% [markdown]
# **Создание финального датасета для модели (изучение поведения признаков)**

# %%
#для датасета колонка match_report будет лишней, поэтому удалим ее. Performance.1 удаляем как дублирующую колонку GA
# однако она может быть полезна для бота, который будет выдавать ссылку на конкретный матч при запросе (если будет необходимость)

# %%
match_stats.columns
# Out:
# Index(['Attendance', 'Performance.3', 'Standard.5', 'Poss', 'Standard.4',
#        'Standard.3', 'offside', 'crosses', 'fouls_drw', 'fouls_com',
#        'intercep', 'Pass Types.5', 'tackles won', 'Int', 'Tackles.1',
#        'Standard.1', 'Standard.2', 'Performance.2', 'Performance',
#        'Opp Formation', 'Formation', 'Captain', 'Referee', 'Performance.1',
#        'Performance.4', 'OwnGoals', 'Ast', 'Penalty Kicks.1',
#        'Penalty Kicks.2', 'Penalty Kicks.3', 'Penalty Kicks', 'Standard.9',
#        'Tkl+Int', 'Standard', 'sec_yel', 'red', 'yellow', 'Standard.8',
#        'match_report', 'result', 'GA', 'GF', 'time', 'round', 'game', 'date',
#        'team', 'day', 'venue', 'opponent', 'season'],
#       dtype='object')

# %%
matches = match_stats.drop(['match_report','round','Pass Types.5','Performance.1','intercep','Standard','tackles won'], axis = 1).reset_index(drop = True)

# %%
#Добавляем колонку total goals, чтобы посмотреть на общее количество голов в матче
# и колонку с разницей - по ней можно понять исход матча и степень выигрыша/проигрыша (отрыва)
matches['GT'] = matches['GA'] + matches['GF']
matches['Gdiff'] = matches['GF'] - matches['GA']

# %%
match_num = matches.select_dtypes(include=['number']).columns

# %%
#корреляци между признаками
matrix = matches[match_num].corr()

# %%
matrix
# Out:
#                  Attendance  Performance.3  Standard.5      Poss  Standard.4  \
# Attendance         1.000000       0.084533    0.005973  0.058485   -0.024105
# Performance.3      0.084533       1.000000    0.146834  0.293525    0.075309
# Standard.5         0.005973       0.146834    1.000000  0.140284    0.786224
# Poss               0.058485       0.293525    0.140284  1.000000    0.052621
# Standard.4        -0.024105       0.075309    0.786224  0.052621    1.000000
# Standard.3         0.033379       0.207323    0.291400  0.261882    0.629351
# Int                0.040877       0.285620    0.118722  0.195536    0.053545
# Tackles.1          0.190481       0.278827    0.118845  0.304818    0.041288
# Standard.1         0.056196       0.197749    0.061613  0.656718   -0.011283
# Standard.2         0.030758       0.167547    0.132700  0.499142    0.280560
# Performance.2      0.114098       0.554574    0.071193  0.027721    0.021425
# Performance        0.140506       0.313837    0.051493  0.045760   -0.001226
# Performance.4     -0.029727       0.336822    0.042772  0.058355    0.052111
# OwnGoals           0.007105      -0.117456   -0.012092 -0.008178   -0.018205
# Ast               -0.015376       0.024713    0.552546  0.144399    0.582404
# Penalty Kicks.1    0.012491       0.075510   -0.003275 -0.014481   -0.004427
# Penalty Kicks.2   -0.011357       0.028032    0.019211 -0.010828    0.014360
# Penalty Kicks.3    0.007634       0.017676    0.021828 -0.006271    0.015187
# Penalty Kicks      0.007212       0.082135    0.009673 -0.018864    0.005687
# Standard.9        -0.015342      -0.000705   -0.026630  0.042234   -0.008127
# Tkl+Int            0.225568       0.178227    0.083685  0.087237    0.016828
# Standard.8        -0.009372       0.003979   -0.015870  0.022292    0.003323
# GA                 0.076945      -0.352146   -0.056511 -0.075915   -0.071621
# GF                -0.036524      -0.006260    0.554446  0.100838    0.613687
# season             0.000540       0.093669    0.068173  0.168397    0.044108
# GT                 0.025500      -0.260185    0.417826  0.028459    0.455900
# Gdiff             -0.072171       0.209801    0.419616  0.116232    0.469968
#
#                  Standard.3       Int  Tackles.1  Standard.1  Standard.2  ...  \
# Attendance         0.033379  0.040877   0.190481    0.056196    0.030758  ...
# Performance.3      0.207323  0.285620   0.278827    0.197749    0.167547  ...
# Standard.5         0.291400  0.118722   0.118845    0.061613    0.132700  ...
# Poss               0.261882  0.195536   0.304818    0.656718    0.499142  ...
# Standard.4         0.629351  0.053545   0.041288   -0.011283    0.280560  ...
# Standard.3         1.000000  0.211765   0.207777    0.184687    0.633125  ...
# Int                0.211765  1.000000   0.407040    0.164470    0.140780  ...
# Tackles.1          0.207777  0.407040   1.000000    0.246043    0.194499  ...
# Standard.1         0.184687  0.164470   0.246043    1.000000    0.769055  ...
# Standard.2         0.633125  0.140780   0.194499    0.769055    1.000000  ...
# Performance.2      0.125035  0.251674   0.210820   -0.017726   -0.021969  ...
# Performance        0.118239  0.261017   0.222789   -0.021930   -0.046584  ...
# Performance.4      0.035049 -0.035736  -0.025279    0.062768    0.090138  ...
# OwnGoals          -0.002627  0.012848  -0.002253   -0.007700   -0.010699  ...
# Ast                0.338823 -0.022906  -0.001914    0.285999    0.511757  ...
# Penalty Kicks.1   -0.006549  0.001824  -0.003215   -0.030207   -0.034002  ...
# Penalty Kicks.2    0.016428  0.015041   0.040260   -0.007802    0.000507  ...
# Penalty Kicks.3    0.000211  0.000660  -0.002430   -0.023770   -0.019759  ...
# Penalty Kicks      0.001630  0.007300   0.013425   -0.035389   -0.033955  ...
# Standard.9         0.052142 -0.017782  -0.011464    0.043455    0.074113  ...
# Tkl+Int            0.082082  0.422650   0.383534    0.033396   -0.016388  ...
# Standard.8         0.055472 -0.016784  -0.018028    0.018610    0.058864  ...
# GA                -0.036830  0.050481   0.028575   -0.104259   -0.130172  ...
# GF                 0.365385 -0.058522  -0.044800    0.268270    0.528733  ...
# season             0.095050 -0.106483  -0.027158    0.131561    0.106369  ...
# GT                 0.275648 -0.011865  -0.016375    0.146468    0.343210  ...
# Gdiff              0.276281 -0.071362  -0.048506    0.249807    0.446545  ...
#
#                  Penalty Kicks.3  Penalty Kicks  Standard.9   Tkl+Int  \
# Attendance              0.007634       0.007212   -0.015342  0.225568
# Performance.3           0.017676       0.082135   -0.000705  0.178227
# Standard.5              0.021828       0.009673   -0.026630  0.083685
# Poss                   -0.006271      -0.018864    0.042234  0.087237
# Standard.4              0.015187       0.005687   -0.008127  0.016828
# Standard.3              0.000211       0.001630    0.052142  0.082082
# Int                     0.000660       0.007300   -0.017782  0.422650
# Tackles.1              -0.002430       0.013425   -0.011464  0.383534
# Standard.1             -0.023770      -0.035389    0.043455  0.033396
# Standard.2             -0.019759      -0.033955    0.074113 -0.016388
# Performance.2           0.010562       0.042742   -0.030440  0.183616
# Performance             0.011862       0.133325   -0.033304  0.230344
# Performance.4           0.001331      -0.190380    0.015246 -0.085274
# OwnGoals               -0.000778      -0.015884    0.001111  0.003443
# Ast                    -0.011456      -0.036508    0.015287 -0.062643
# Penalty Kicks.1         0.015826       0.874213    0.015134  0.020119
# Penalty Kicks.2        -0.013193       0.407149    0.009985  0.008198
# Penalty Kicks.3         1.000000       0.257234    0.007793  0.006614
# Penalty Kicks           0.257234       1.000000    0.019701  0.022099
# Standard.9              0.007793       0.019701    1.000000 -0.017010
# Tkl+Int                 0.006614       0.022099   -0.017010  1.000000
# Standard.8              0.014312       0.016590    0.890864 -0.018749
# GA                      0.008256       0.245356   -0.021904  0.092924
# GF                      0.001520      -0.026652    0.227320 -0.107480
# season                 -0.008706       0.010561    0.024517 -0.057495
# GT                      0.007236       0.155622    0.172222 -0.021639
# Gdiff                  -0.003964      -0.167727    0.171271 -0.131191
#
#                  Standard.8        GA        GF    season        GT     Gdiff
# Attendance        -0.009372  0.076945 -0.036524  0.000540  0.025500 -0.072171
# Performance.3      0.003979 -0.352146 -0.006260  0.093669 -0.260185  0.209801
# Standard.5        -0.015870 -0.056511  0.554446  0.068173  0.417826  0.419616
# Poss               0.022292 -0.075915  0.100838  0.168397  0.028459  0.116232
# Standard.4         0.003323 -0.071621  0.613687  0.044108  0.455900  0.469968
# Standard.3         0.055472 -0.036830  0.365385  0.095050  0.275648  0.276281
# Int               -0.016784  0.050481 -0.058522 -0.106483 -0.011865 -0.071362
# Tackles.1         -0.018028  0.028575 -0.044800 -0.027158 -0.016375 -0.048506
# Standard.1         0.018610 -0.104259  0.268270  0.131561  0.146468  0.249807
# Standard.2         0.058864 -0.130172  0.528733  0.106369  0.343210  0.446545
# Performance.2     -0.023635  0.169276 -0.122041  0.054728  0.021604 -0.187740
# Performance       -0.033788  0.578570 -0.175828  0.064208  0.273489 -0.474017
# Performance.4      0.024815 -0.674560  0.124580  0.001322 -0.385403  0.496782
# OwnGoals          -0.002536  0.170516 -0.020564  0.003017  0.106464 -0.117985
# Ast                0.019645 -0.154918  0.833978  0.028785  0.577849  0.673690
# Penalty Kicks.1    0.008822  0.276860 -0.032310  0.002602  0.173754 -0.190817
# Penalty Kicks.2    0.011980  0.005017  0.002978  0.024292  0.006097 -0.000982
# Penalty Kicks.3    0.014312  0.008256  0.001520 -0.008706  0.007236 -0.003964
# Penalty Kicks      0.016590  0.245356 -0.026652  0.010561  0.155622 -0.167727
# Standard.9         0.890864 -0.021904  0.227320  0.024517  0.172222  0.171271
# Tkl+Int           -0.018749  0.092924 -0.107480 -0.057495 -0.021639 -0.131191
# Standard.8         1.000000 -0.030794  0.258809  0.018715  0.191839  0.198557
# GA                -0.030794  1.000000 -0.174392 -0.000392  0.579855 -0.729303
# GF                 0.258809 -0.174392  1.000000  0.024272  0.701113  0.800891
# season             0.018715 -0.000392  0.024272  1.000000  0.019798  0.017104
# GT                 0.191839  0.579855  0.701113  0.019798  1.000000  0.134534
# Gdiff              0.198557 -0.729303  0.800891  0.017104  0.134534  1.000000
#
# [27 rows x 27 columns]

# %%
plt.figure(figsize = (10,8))
sns.heatmap(matrix)
# Out:
# <Axes: >

# %% [markdown]
# На данном этапе как целевые переменные будет рассматривать Gdiff (в дальнейшем могут быть еще добавлены GT и другие)

# %%
matrix['Gdiff'].sort_values(ascending = False)
# Out:
# Gdiff              1.000000
# GF                 0.800891
# Ast                0.673690
# Performance.4      0.496782
# Standard.4         0.469968
# Standard.2         0.446545
# Standard.5         0.419616
# Standard.3         0.276281
# Standard.1         0.249807
# Performance.3      0.209801
# Standard.8         0.198557
# Standard.9         0.171271
# GT                 0.134534
# Poss               0.116232
# season             0.017104
# Penalty Kicks.2   -0.000982
# Penalty Kicks.3   -0.003964
# Tackles.1         -0.048506
# Int               -0.071362
# Attendance        -0.072171
# OwnGoals          -0.117985
# Tkl+Int           -0.131191
# Penalty Kicks     -0.167727
# Performance.2     -0.187740
# Penalty Kicks.1   -0.190817
# Performance       -0.474017
# GA                -0.729303
# Name: Gdiff, dtype: float64

# %% [markdown]
# Наиболее скоррелированными с переменной Gdiff являются Ast, Performance.4, Performance, Standard.4, Standard.2,Standard.3, Standard.5, Standard.1,Performance.3,Penalty Kicks.1, Standard.8

# %%
cols = matrix['Gdiff'].sort_values(ascending = False).apply(abs).sort_values(ascending = False).index[:14]

# %%
sns.pairplot(matches[cols])

# %% [markdown]
# Визуализации

# %%
sns.scatterplot(data = matches, x = 'Standard.2',y = 'GF')
plt.title('Зависимость числа голов команды от общего числа ударов')
plt.xlabel('Количество ударов')
plt.ylabel('Количество голов')
# Out:
# Text(0, 0.5, 'Количество голов')

# %%
matches.groupby(by=['team','venue'])['Gdiff'].sum()
# Out:
# team       venue
# Ajaccio    Away       -1
# Alavés     Away        0
#            Home        7
# Almería    Away       -1
# Amiens     Away       -6
#                       ..
# Wolfsburg  Away      -11
#            Home       39
# Wolves     Away       14
#            Home       30
#            Neutral    -1
# Name: Gdiff, Length: 337, dtype: int64

# %%
sns.barplot(data = matches, x = 'venue', y = 'Gdiff')
plt.title('Зависимость числа голов команды от места проведения матча')
plt.xlabel('Место проведения')
plt.ylabel('Разница (GF - GA)')
# Out:
# Text(0, 0.5, 'Разница (GF - GA)')

# %%
sns.catplot(
    data=matches, x="venue", y="GF", col="team",
    kind="bar", height=4, aspect=.6,
)
plt.title('Исходы матча в зависимости от места игры - дома/в гостях/нейтральная тер')
plt.xlabel('Место')
plt.ylabel('Разница между голами')
# Out:
# Text(35285.80839821242, 0.5, 'Разница между голами')

# %%
sns.scatterplot(data=matches, x = 'Gdiff', y = 'Tkl+Int')
plt.title('Зависимость исхода матча для команды от их оборонительной способности')
plt.xlabel('Разница между забитыми и пропущенными голами')
plt.ylabel('Tackles + Interceptions')
# Out:
# Text(0, 0.5, 'Tackles + Interceptions')

# %%
matches.groupby(by = "Referee")[['GT','Penalty Kicks']].mean().sort_values(by='Penalty Kicks', ascending = False)
# Out:
#                              GT  Penalty Kicks
# Referee
# Luca Massimi           2.000000            1.0
# Aleksandrs Anufrijevs  2.000000            1.0
# Alexandre Boucaut      2.000000            1.0
# Luigi Pillitteri       3.000000            1.0
# Constantin Colțescu    4.000000            1.0
# ...                         ...            ...
# Michael Salisbury      3.071429            0.0
# Michael Tykgaard       1.000000            0.0
# Michal Očenáš          1.000000            0.0
# Mickael Lesage         2.000000            0.0
# Əliyar Ağayev          3.600000            0.0
#
# [445 rows x 2 columns]

# %%
matches.to_csv("teams_matches_stats.csv")

# %%
np.transpose(matches.describe(include = 'all'))
# Out:
#                   count unique                                 top  freq  \
# Attendance       9745.0    NaN                                 NaN   NaN
# Performance.3    9745.0    NaN                                 NaN   NaN
# Standard.5       9745.0    NaN                                 NaN   NaN
# Poss             9745.0    NaN                                 NaN   NaN
# Standard.4       9745.0    NaN                                 NaN   NaN
# Standard.3       9745.0    NaN                                 NaN   NaN
# offside            9745     12                                   1  2490
# crosses            9745     62                                   0   617
# fouls_drw          9745     30                                  11   925
# fouls_com          9745     30                                  12   899
# Int              9745.0    NaN                                 NaN   NaN
# Tackles.1        9745.0    NaN                                 NaN   NaN
# Standard.1       9745.0    NaN                                 NaN   NaN
# Standard.2       9745.0    NaN                                 NaN   NaN
# Performance.2    9745.0    NaN                                 NaN   NaN
# Performance      9745.0    NaN                                 NaN   NaN
# Opp Formation      9745     24                             4-2-3-1  2462
# Formation          9745     23                             4-2-3-1  2483
# Captain            9745   1016                                   0   319
# Referee            9745    445                         Felix Brych   297
# Performance.4    9745.0    NaN                                 NaN   NaN
# OwnGoals         9745.0    NaN                                 NaN   NaN
# Ast              9745.0    NaN                                 NaN   NaN
# Penalty Kicks.1  9745.0    NaN                                 NaN   NaN
# Penalty Kicks.2  9745.0    NaN                                 NaN   NaN
# Penalty Kicks.3  9745.0    NaN                                 NaN   NaN
# Penalty Kicks    9745.0    NaN                                 NaN   NaN
# Standard.9       9745.0    NaN                                 NaN   NaN
# Tkl+Int          9745.0    NaN                                 NaN   NaN
# sec_yel            9745      3                                   0  9395
# red                9745      4                                   0  9078
# yellow             9745     10                                   1  2760
# Standard.8       9745.0    NaN                                 NaN   NaN
# result             9745      3                                   W  4541
# GA               9745.0    NaN                                 NaN   NaN
# GF               9745.0    NaN                                 NaN   NaN
# time               9745     72                            15:30:00  2747
# game               9745   6330  2018-04-14 Hoffenheim-Hamburger SV     2
# date               9745   1451                          2023-11-01    31
# team               9745    148                       Bayern Munich   360
# day                9745      7                                 Sat  3144
# venue              9745      3                                Away  4994
# opponent           9745    750                       Bayern Munich   311
# season           9745.0    NaN                                 NaN   NaN
# GT               9745.0    NaN                                 NaN   NaN
# Gdiff            9745.0    NaN                                 NaN   NaN
#
#                          mean           std     min     25%      50%      75%  \
# Attendance       28944.449461  23382.785037     0.0  8000.0  26000.0  47069.0
# Performance.3       63.141293     32.976173  -100.0    50.0     66.7    100.0
# Standard.5           0.293127      0.261213     0.0     0.0     0.25      0.5
# Poss                49.270703     16.924304     0.0    42.0     52.0     60.0
# Standard.4             0.1127      0.120143     0.0     0.0     0.09     0.17
# Standard.3          33.793874     17.719791     0.0    23.1     33.3     44.4
# offside                   NaN           NaN     NaN     NaN      NaN      NaN
# crosses                   NaN           NaN     NaN     NaN      NaN      NaN
# fouls_drw                 NaN           NaN     NaN     NaN      NaN      NaN
# fouls_com                 NaN           NaN     NaN     NaN      NaN      NaN
# Int                  9.797435      5.014656     0.0     7.0     10.0     13.0
# Tackles.1            9.551975      4.679023     0.0     7.0     10.0     12.0
# Standard.1          12.896152      6.474125     0.0     9.0     13.0     17.0
# Standard.2           4.569523      2.933638     0.0     3.0      4.0      6.0
# Performance.2        2.683325      2.035773     0.0     1.0      2.0      4.0
# Performance          3.923961       2.62536     0.0     2.0      4.0      6.0
# Opp Formation             NaN           NaN     NaN     NaN      NaN      NaN
# Formation                 NaN           NaN     NaN     NaN      NaN      NaN
# Captain                   NaN           NaN     NaN     NaN      NaN      NaN
# Referee                   NaN           NaN     NaN     NaN      NaN      NaN
# Performance.4        0.291021      0.456735     0.0     0.0      0.0      1.0
# OwnGoals             0.037352      0.193915     0.0     0.0      0.0      0.0
# Ast                   1.18707      1.217516     0.0     0.0      1.0      2.0
# Penalty Kicks.1      0.110108      0.329336     0.0     0.0      0.0      0.0
# Penalty Kicks.2      0.022473      0.156967     0.0     0.0      0.0      0.0
# Penalty Kicks.3       0.00862       0.09355     0.0     0.0      0.0      0.0
# Penalty Kicks        0.140893      0.375998     0.0     0.0      0.0      0.0
# Standard.9           0.167984      0.406739     0.0     0.0      0.0      0.0
# Tkl+Int             18.633453     13.898296     0.0     0.0     22.0     29.0
# sec_yel                   NaN           NaN     NaN     NaN      NaN      NaN
# red                       NaN           NaN     NaN     NaN      NaN      NaN
# yellow                    NaN           NaN     NaN     NaN      NaN      NaN
# Standard.8           0.133915      0.364169     0.0     0.0      0.0      0.0
# result                    NaN           NaN     NaN     NaN      NaN      NaN
# GA                   1.339354      1.261595     0.0     0.0      1.0      2.0
# GF                   1.714315      1.441478     0.0     1.0      1.0      2.0
# time                      NaN           NaN     NaN     NaN      NaN      NaN
# game                      NaN           NaN     NaN     NaN      NaN      NaN
# date                      NaN           NaN     NaN     NaN      NaN      NaN
# team                      NaN           NaN     NaN     NaN      NaN      NaN
# day                       NaN           NaN     NaN     NaN      NaN      NaN
# venue                     NaN           NaN     NaN     NaN      NaN      NaN
# opponent                  NaN           NaN     NaN     NaN      NaN      NaN
# season            2034.017547     214.14123  1718.0  1819.0   2021.0   2223.0
# GT                   3.053669      1.742181     0.0     2.0      3.0      4.0
# Gdiff                0.374962      2.074552    -8.0    -1.0      0.0      2.0
#
#                      max
# Attendance       98299.0
# Performance.3      100.0
# Standard.5           1.0
# Poss                87.0
# Standard.4           1.0
# Standard.3         100.0
# offside              NaN
# crosses              NaN
# fouls_drw            NaN
# fouls_com            NaN
# Int                 38.0
# Tackles.1           31.0
# Standard.1          44.0
# Standard.2          25.0
# Performance.2       19.0
# Performance         20.0
# Opp Formation        NaN
# Formation            NaN
# Captain              NaN
# Referee              NaN
# Performance.4        2.0
# OwnGoals             2.0
# Ast                 11.0
# Penalty Kicks.1      3.0
# Penalty Kicks.2      4.0
# Penalty Kicks.3      2.0
# Penalty Kicks        4.0
# Standard.9           3.0
# Tkl+Int             60.0
# sec_yel              NaN
# red                  NaN
# yellow               NaN
# Standard.8           3.0
# result               NaN
# GA                   8.0
# GF                   9.0
# time                 NaN
# game                 NaN
# date                 NaN
# team                 NaN
# day                  NaN
# venue                NaN
# opponent             NaN
# season            2425.0
# GT                  11.0
# Gdiff                9.0
