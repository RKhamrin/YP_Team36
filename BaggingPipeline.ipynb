# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

from sklearn.feature_selection import f_classif, chi2, mutual_info_classif, SelectKBest, SelectPercentile
from sklearn.ensemble import BaggingClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder, TargetEncoder, MaxAbsScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.feature_selection import SelectKBest, f_classif, RFE
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline

from OutliersCorrection import OutliersIQRDeleter, OutliersLOFDeleter, OutliersIQRCorrector, OutliersLOFCorrector

# %% [markdown]
# ## Сбор данных

# %%
df = pd.read_csv('teams_matches_stats-2.csv')
df.drop('Unnamed: 0', axis = 1, inplace = True)
df.sort_values(by = 'date', ignore_index = 'True', inplace = True)
y = list(map((lambda i: 1 if i == 'W' else 0), df['result']))
data = df.drop([ 'Opp Formation', 'Formation', 'Captain', 'Referee','result','time','game', 'day', 'season','GT', 'Gdiff'], axis = 1)

# %%
def getStats(team, date, df = data):
    srez = df[(df['team']== team)&(df['date'] < date)]
    if 0 < len(srez) < 10:
      stats = srez.drop(['team','date', 'opponent', 'venue'], axis = 1).sum()/len(srez)
    elif len(srez) >= 10:
      stats = srez.drop(['team','date', 'opponent', 'venue'], axis = 1)[-10:].sum()/10
    else:
      srez = df[(df['team']== team)&(df['date'] <= date)]
      stats = srez.drop(['team','date', 'opponent', 'venue'], axis = 1).sum()

    return stats.values.tolist()

# %%
def GetTrain(data):
  features = []
  for i in range(len(data)):
    team1 = getStats(data['team'][i], data['date'][i])
    team2 = getStats(data['opponent'][i], data['date'][i])
    diff = [a - b for a, b in zip(team1, team2)]
    features.append(diff)
  return features

# %%
feat_data = GetTrain(data)
x = pd.DataFrame(feat_data, columns=data.drop(['team', 'date', 'opponent', 'venue'], axis=1).columns)
x = pd.concat([x, data['venue']], axis=1)

# %%
num_cols = x.dtypes[(x.dtypes == 'int64') | (x.dtypes == 'float64')].index.tolist()
cat_cols = x.dtypes[x.dtypes == 'object'].index.tolist()

# %% [markdown]
# ## OHE + StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,
                                                    train_size=0.8,
                                                    random_state=125)
X_train, X_test = X_train.reset_index(drop=True), X_test.reset_index(drop=True)

# %%
enc = OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse_output = False)
encd = enc.fit_transform(X_train[['venue']])
encd_test = enc.transform(X_test[['venue']])

one_hot_df = pd.DataFrame(encd, columns=enc.get_feature_names_out(['venue']))
one_hot_df_test = pd.DataFrame(encd_test, columns=enc.get_feature_names_out(['venue']))


X_train = pd.concat([X_train.drop(['venue'], axis = 1), one_hot_df], axis = 1)
X_test = pd.concat([X_test.drop(['venue'], axis = 1), one_hot_df_test], axis = 1)

# %%
normalizer = StandardScaler()
scaler = normalizer.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
model = BaggingClassifier()
model.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
print(f1_score(y_test, model.predict(X_test)))
# Out:
# 0.5347137637028014

# %% [markdown]
# ## OHE + MinMaxScaler

# %%
normalizer = MinMaxScaler()
scaler = normalizer.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
model = BaggingClassifier()
model.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
print(f1_score(y_test, model.predict(X_test)))
# Out:
# 0.536144578313253

# %% [markdown]
# ## OrdinalEnc + StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,
                                                    train_size=0.8,
                                                    random_state=125)
X_train, X_test = X_train.reset_index(drop=True), X_test.reset_index(drop=True)

# %%
enc = OrdinalEncoder()
encd = enc.fit_transform(X_train[['venue']])
encd_test = enc.transform(X_test[['venue']])

one_hot_df = pd.DataFrame(encd, columns=enc.get_feature_names_out(['venue']))
one_hot_df_test = pd.DataFrame(encd_test, columns=enc.get_feature_names_out(['venue']))


X_train = pd.concat([X_train.drop(['venue'], axis = 1), one_hot_df], axis = 1)
X_test = pd.concat([X_test.drop(['venue'], axis = 1), one_hot_df_test], axis = 1)

# %%
normalizer = StandardScaler()
scaler = normalizer.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
model = BaggingClassifier()
model.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
print(f1_score(y_test, model.predict(X_test)))
# Out:
# 0.5315370483772198

# %% [markdown]
# ## OrdincalEnc + MinMaxScaler

# %%
normalizer = MinMaxScaler()
scaler = normalizer.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
model = BaggingClassifier()
model.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
print(f1_score(y_test, model.predict(X_test)))
# Out:
# 0.5226006191950464

# %% [markdown]
# ## TargetEnc + StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,
                                                    train_size=0.8,
                                                    random_state=125)
X_train, X_test = X_train.reset_index(drop=True), X_test.reset_index(drop=True)

# %%
enc = TargetEncoder()
encd = enc.fit_transform(X_train[['venue']], y_train)
encd_test = enc.transform(X_test[['venue']])

one_hot_df = pd.DataFrame(encd, columns=enc.get_feature_names_out(['venue']))
one_hot_df_test = pd.DataFrame(encd_test, columns=enc.get_feature_names_out(['venue']))


X_train = pd.concat([X_train.drop(['venue'], axis = 1), one_hot_df], axis = 1)
X_test = pd.concat([X_test.drop(['venue'], axis = 1), one_hot_df_test], axis = 1)

# %%
normalizer = StandardScaler()
scaler = normalizer.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
model = BaggingClassifier()
model.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
print(f1_score(y_test, model.predict(X_test)))
# Out:
# 0.5206874602164226

# %% [markdown]
# ## TargetEnc + MinMaxScaler

# %%
normalizer = MinMaxScaler()
scaler = normalizer.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
model = BaggingClassifier()
model.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
print(f1_score(y_test, model.predict(X_test)))
# Out:
# 0.529192546583851

# %% [markdown]
# ## Подбор гиперпараметров лучшей модели

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,
                                                    train_size=0.8,
                                                    random_state=125)
X_train, X_test = X_train.reset_index(drop=True), X_test.reset_index(drop=True)

enc = OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse_output = False)
encd = enc.fit_transform(X_train[['venue']])
encd_test = enc.transform(X_test[['venue']])

one_hot_df = pd.DataFrame(encd, columns=enc.get_feature_names_out(['venue']))
one_hot_df_test = pd.DataFrame(encd_test, columns=enc.get_feature_names_out(['venue']))


X_train = pd.concat([X_train.drop(['venue'], axis = 1), one_hot_df], axis = 1)
X_test = pd.concat([X_test.drop(['venue'], axis = 1), one_hot_df_test], axis = 1)

normalizer = MinMaxScaler()
scaler = normalizer.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_val_score
import optuna

def objective_bagging(trial):
    max_samples = trial.suggest_int("max_samples", 1, 100)
    n_estimators = trial.suggest_int("n_estimators", 1200, 2000)
    max_features = trial.suggest_int("max_features", 1, 32)
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])

    model = BaggingClassifier(
        n_estimators=n_estimators,
        max_samples=max_samples,
        max_features=max_features,
        bootstrap=bootstrap
    )

    score = cross_val_score(model, X_train, y_train, cv=3, scoring="f1", n_jobs=-1).mean()
    return score

study = optuna.create_study(direction="maximize")
study.optimize(objective_bagging, n_trials=100)
# Out:
# [I 2025-03-16 01:28:08,029] A new study created in memory with name: no-name-c8ae25e2-84f0-46bb-bd0d-7ce7c323de14
# [I 2025-03-16 01:28:10,869] Trial 0 finished with value: 0.5182575140538287 and parameters: {'max_samples': 60, 'n_estimators': 1284, 'max_features': 2, 'bootstrap': False}. Best is trial 0 with value: 0.5182575140538287.
# [I 2025-03-16 01:28:13,720] Trial 1 finished with value: 0.6113934666264859 and parameters: {'max_samples': 81, 'n_estimators': 1320, 'max_features': 13, 'bootstrap': True}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:16,156] Trial 2 finished with value: 0.5113301527171116 and parameters: {'max_samples': 63, 'n_estimators': 1337, 'max_features': 2, 'bootstrap': True}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:17,729] Trial 3 finished with value: 0.519500990662253 and parameters: {'max_samples': 6, 'n_estimators': 1435, 'max_features': 10, 'bootstrap': True}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:20,435] Trial 4 finished with value: 0.6071716092531566 and parameters: {'max_samples': 66, 'n_estimators': 1957, 'max_features': 12, 'bootstrap': True}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:22,616] Trial 5 finished with value: 0.5509636993353463 and parameters: {'max_samples': 13, 'n_estimators': 1945, 'max_features': 7, 'bootstrap': True}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:24,276] Trial 6 finished with value: 0.5330246494522605 and parameters: {'max_samples': 6, 'n_estimators': 1346, 'max_features': 8, 'bootstrap': False}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:26,612] Trial 7 finished with value: 0.6095959648845628 and parameters: {'max_samples': 91, 'n_estimators': 1467, 'max_features': 15, 'bootstrap': True}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:28,499] Trial 8 finished with value: 0.6107711483780176 and parameters: {'max_samples': 98, 'n_estimators': 1212, 'max_features': 10, 'bootstrap': True}. Best is trial 1 with value: 0.6113934666264859.
# [I 2025-03-16 01:28:30,398] Trial 9 finished with value: 0.5993209265232554 and parameters: {'max_samples': 70, 'n_estimators': 1291, 'max_features': 10, 'bootstrap': False}. Best is trial 1 with value: 0.6113934666264859.
 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:04,445] Trial 85 finished with value: 0.6188622876870457 and parameters: {'max_samples': 85, 'n_estimators': 1583, 'max_features': 30, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:07,878] Trial 86 finished with value: 0.6212996220366569 and parameters: {'max_samples': 90, 'n_estimators': 1636, 'max_features': 32, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:11,238] Trial 87 finished with value: 0.619238130452418 and parameters: {'max_samples': 96, 'n_estimators': 1650, 'max_features': 29, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:14,182] Trial 88 finished with value: 0.6190973093693466 and parameters: {'max_samples': 82, 'n_estimators': 1620, 'max_features': 25, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:17,351] Trial 89 finished with value: 0.6210459287710262 and parameters: {'max_samples': 100, 'n_estimators': 1444, 'max_features': 32, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:19,530] Trial 90 finished with value: 0.602376161663241 and parameters: {'max_samples': 91, 'n_estimators': 1520, 'max_features': 9, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:22,938] Trial 91 finished with value: 0.6178497310147174 and parameters: {'max_samples': 89, 'n_estimators': 1649, 'max_features': 32, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:26,390] Trial 92 finished with value: 0.6221575700026719 and parameters: {'max_samples': 86, 'n_estimators': 1686, 'max_features': 31, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:29,773] Trial 93 finished with value: 0.623149747242061 and parameters: {'max_samples': 87, 'n_estimators': 1680, 'max_features': 31, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:32,886] Trial 94 finished with value: 0.6191499713442085 and parameters: {'max_samples': 86, 'n_estimators': 1578, 'max_features': 30, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:36,057] Trial 95 finished with value: 0.6180157850451365 and parameters: {'max_samples': 78, 'n_estimators': 1754, 'max_features': 26, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:39,507] Trial 96 finished with value: 0.6204202579669775 and parameters: {'max_samples': 84, 'n_estimators': 1781, 'max_features': 30, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:42,558] Trial 97 finished with value: 0.6164798724838164 and parameters: {'max_samples': 87, 'n_estimators': 1547, 'max_features': 28, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:45,907] Trial 98 finished with value: 0.6190382764653098 and parameters: {'max_samples': 80, 'n_estimators': 1721, 'max_features': 31, 'bootstrap': False}. Best is trial 78 with value: 0.623590098392456.
# [I 2025-03-16 01:32:49,238] Trial 99 finished with value: 0.6191483350451411 and parameters: {'max_samples': 95, 'n_estimators': 1693, 'max_features': 29, 'bootstrap': True}. Best is trial 78 with value: 0.623590098392456.

# %%
study.best_params, study.best_trial
# Out:
# ({'max_samples': 100,
#   'n_estimators': 1530,
#   'max_features': 26,
#   'bootstrap': False},
#  FrozenTrial(number=78, state=TrialState.COMPLETE, values=[0.623590098392456], datetime_start=datetime.datetime(2025, 3, 16, 1, 31, 39, 793128), datetime_complete=datetime.datetime(2025, 3, 16, 1, 31, 42, 851747), params={'max_samples': 100, 'n_estimators': 1530, 'max_features': 26, 'bootstrap': False}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'max_samples': IntDistribution(high=100, log=False, low=1, step=1), 'n_estimators': IntDistribution(high=2000, log=False, low=1200, step=1), 'max_features': IntDistribution(high=32, log=False, low=1, step=1), 'bootstrap': CategoricalDistribution(choices=(True, False))}, trial_id=78, value=None))

# %% [markdown]
# ## Лучшая модель

# %%
model = BaggingClassifier(**study.best_params)
model.fit(X_train, y_train)
print(f1_score(y_test, model.predict(X_test)))
# Out:
# 0.5964099594672843
